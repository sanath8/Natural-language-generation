# %%
import numpy as np
from keras.utils.data_utils import get_file
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.optimizers import RMSprop
import sys
import random
import math
import re
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load Text File and Build Vocabulary

# %%
data_path = "test_data_long.txt"
raw_text = open(data_path).read().lower()

# generate list of unique characters, but only include words and some punctuation marks
pattern = re.compile('[a-z]+|\!|\n|\.|,|;')
all_words = re.findall(pattern, raw_text)

unique_words = sorted(set(all_words))

word_to_int = dict((c, i) for i, c in enumerate(unique_words))

#print(unique_words)
print(word_to_int)

# later used to make outputs more readable by converting ints back to characters
int_to_word = dict((i, c) for i, c in enumerate(unique_words))

total_num_words = len(all_words)
len_vocab = len(unique_words)

print("Total number of words:\t" + str(total_num_words))
print("Length of vocabulary:\t" + str(len_vocab))
# Out:
# {'\n': 0, '!': 1, ',': 2, '.': 3, ';': 4, 'a': 5, 'abduct': 6, 'abducting': 7, 'abduction': 8, 'abiding': 9, 'ability': 10, 'able': 11, 'about': 12, 'above': 13, 'abreast': 14, 'abroad': 15, 'abruptly': 16, 'absence': 17, 'absolute': 18, 'absolutely': 19, 'absorbed': 20, 'absorbing': 21, 'abstemious': 22, 'absurd': 23, 'academic': 24, 'accent': 25, 'accept': 26, 'accepted': 27, 'accident': 28, 'accidental': 29, 'accidents': 30, 'accompanied': 31, 'accord': 32, 'according': 33, 'account': 34, 'accounted': 35, 'accounts': 36, 'accumulate': 37, 'accurate': 38, 'accurately': 39, 'accused': 40, 'acid': 41, 'acquaintance': 42, 'acquaintances': 43, 'acquired': 44, 'acquisition': 45, 'acrimonious': 46, 'across': 47, 'act': 48, 'acted': 49, 'acting': 50, 'action': 51, 'active': 52, 'activity': 53, 'actual': 54, 'actually': 55, 'adam': 56, 'adamant': 57, 'add': 58, 'added': 59, 'adding': 60, 'addition': 61, 'address': 62, 'addressed': 63, 'addressing': 64, 'adequate': 65, 'adhering': 66, 'admirable': 67, 'admirably': 68, 'admiration': 69, 'admire': 70, 'admit': 71, 'admits': 72, 'admitted': 73, 'admittedly': 74, 'adopting': 75, 'adorned': 76, 'advance': 77, 'advanced': 78, 'advancing': 79, 'advantage': 80, 'advantages': 81, 'advice': 82, 'advisability': 83, 'advisable': 84, 'advised': 85, 'advisedly': 86, 'affable': 87, 'affably': 88, 'affair': 89, 'affairs': 90, 'affect': 91, 'affectionate': 92, 'afford': 93, 'affording': 94, 'afoot': 95, 'afraid': 96, 'aft': 97, 'after': 98, 'afternoon': 99, 'afterwards': 100, 'again': 101, 'against': 102, 'age': 103, 'aged': 104, 'agent': 105, 'agents': 106, 'ages': 107, 'aghast': 108, 'agitated': 109, 'agitation': 110, 'ago': 111, 'agonised': 112, 'agonising': 113, 'agony': 114, 'agree': 115, 'agreeable': 116, 'agreed': 117, 'agreeing': 118, 'ah': 119, 'ahead': 120, 'aid': 121, 'aimed': 122, 'ain': 123, 'air': 124, 'airedale': 125, 'airedales': 126, 'airy': 127, 'alarm': 128, 'alarmed': 129, 'alarming': 130, 'aliases': 131, 'alibi': 132, 'alice': 133, 'alike': 134, 'alive': 135, 'all': 136, 'allow': 137, 'allowances': 138, 'allowed': 139, 'allowing': 140, 'allude': 141, 'alluded': 142, 'allusion': 143, 'almighty': 144, 'almost': 145, 'alone': 146, 'along': 147, 'already': 148, 'also': 149, 'alter': 150, 'alterations': 151, 'altered': 152, 'alternative': 153, 'alternatives': 154, 'altogether': 155, 'always': 156, 'am': 157, 'amateur': 158, 'amazed': 159, 'amazement': 160, 'amazing': 161, 'ambassador': 162, 'amenable': 163, 'america': 164, 'american': 165, 'amiss': 166, 'ammunition': 167, 'amongst': 168, 'amount': 169, 'ample': 170, 'amply': 171, 'amuses': 172, 'an': 173, 'anarchists': 174, 'ancient': 175, 'and': 176, 'anger': 177, 'angle': 178, 'angrily': 179, 'angry': 180, 'animal': 181, 'animals': 182, 'animosity': 183, 'ankle': 184, 'announce': 185, 'announced': 186, 'announcement': 187, 'announcing': 188, 'annoyance': 189, 'annoyed': 190, 'annoying': 191, 'annoys': 192, 'annual': 193, 'another': 194, 'answer': 195, 'answered': 196, 'ante': 197, 'anticipated': 198, 'anticipation': 199, 'antiquated': 200, 'anxious': 201, 'anxiously': 202, 'any': 203, 'anybody': 204, 'anyone': 205, 'anything': 206, 'anyway': 207, 'anywhere': 208, 'apace': 209, 'apart': 210, 'apathetic': 211, 'apologetically': 212, 'apologise': 213, 'apologised': 214, 'apparent': 215, 'apparently': 216, 'apparition': 217, 'appealed': 218, 'appealing': 219, 'appealingly': 220, 'appeals': 221, 'appear': 222, 'appearance': 223, 'appearances': 224, 'appeared': 225, 'appearing': 226, 'appears': 227, 'appetite': 228, 'applied': 229, 'applies': 230, 'appointment': 231, 'appreciable': 232, 'appreciate': 233, 'appreciated': 234, 'approached': 235, 'approaches': 236, 'approaching': 237, 'approve': 238, 'approved': 239, 'approvingly': 240, 'april': 241, 'apt': 242, 'aptitude': 243, 'archibald': 244, 'archie': 245, 'architect': 246, 'ard': 247, 'are': 248, 'aren': 249, 'arise': 250, 'arises': 251, 'arm': 252, 'armed': 253, 'arms': 254, 'army': 2 ...
# Total number of words:	100440
# Length of vocabulary:	5686

# %% [markdown]
# ### Define Model
#
# I will use a single hidden LSTM layer with 256 memory units and a dropout probability of 20%. The dense layer will use a softmax activation to output a probability prediction for each of the characters, between 0 and 1.

# %%
sequence_length = 5

learning_rate = 0.01
optimizer = RMSprop(lr=learning_rate)
num_memory_units = 256

model = Sequential()

model.add(LSTM(num_memory_units, input_shape=(sequence_length, len_vocab)))
model.add(Dropout(0.2))
model.add(Dense(len_vocab))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# "We are not interested in the most accurate (classification accuracy) model of the training dataset. This would be a model that predicts each character in the training dataset perfectly. Instead we are interested in a generalization of the dataset that minimizes the chosen loss function. We are seeking a balance between generalization and overfitting but short of memorization."

# %% [markdown]
# ## Predict

# %%
def add_temperature(predictions, temperature=1.0):

    predictions = np.asarray(predictions).astype('float64')
    predictions = np.log(predictions) / temperature
    exp_predictions = np.exp(predictions)
    predictions = exp_predictions / np.sum(exp_predictions)
    
    probabilities = np.random.multinomial(1, predictions, 1)
    return np.argmax(probabilities)

# %%
def get_random_word(n=1, array=unique_words):

    random_words = []
    
    random_indices = random.sample(range(0, len(array)), n)
    
    # in-place shuffle
    random.shuffle(array)

    # take the first n elements of the now randomized array
    return array[:n]

# %%
# load weights
weights_path = '_weights.hdf5'
model.load_weights(weights_path)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# ### Handle User Input

# %%
random_seed = False

# %%
# user_input = "this is some string entered by a user this is some string entered by a user this is some string entered by a user"
user_input = "this is some string entered by a\nuser"
words_to_generate = 400
seed_sentence = ["\n"] * sequence_length

if not random_seed:

    pattern = re.compile('[a-z]+|\!|\n|\.|,|;')
    user_input_edit = user_input.lower()
    user_input_edit = re.findall(pattern, user_input)

    if (len(user_input_edit) > sequence_length):
        # need to truncate
        
        seed_sentence = user_input_edit[:sequence_length]
        
    elif (len(user_input_edit) < sequence_length):
        # need to pad
        
        # get number of elements missing in user input
        missing_elems = sequence_length - len(user_input_edit)
        
        seed_sentence[0:missing_elems+1] = get_random_word(missing_elems)
        seed_sentence[-(len(user_input_edit)):] = user_input_edit
        
    # check all words provided are in the vocabulary
    for i, word in enumerate(seed_sentence):
        # if it doesnt exist, replace it with one that does
        if word not in word_to_int.keys():
            seed_sentence[i] = get_random_word()[0]
    
    print('-> seed: "' + user_input + '" ...\n')

else:

    # pick a random seed
    random_index_start = np.random.randint(0, total_num_words - sequence_length - 1)
    seed_sentence = all_words[random_index_start : random_index_start + sequence_length]
    
    print('-> seed: "' + ' '.join(seed_sentence) + '" ...')
# Out:
# -> seed: "this is some string entered by a
# user" ...

# %%
for i in range(words_to_generate):
        
    x_input = np.zeros((1, sequence_length, len_vocab))
    for t, word in enumerate(seed_sentence):
        x_input[0, t, word_to_int[word]] = 1.

    predictions = model.predict(x_input, verbose=0)[0]
    predicted_word_index = add_temperature(predictions, 0.5)
    predicted_word = int_to_word[predicted_word_index]

    seed_sentence = seed_sentence[1:] + list([predicted_word])

    if re.match('[a-z]', predicted_word):
        sys.stdout.write(" " + predicted_word)
    else:
        sys.stdout.write(predicted_word)

    sys.stdout.flush()
# Out:
#  distance twenty saluted cottage killed butler till egg knowledge train stroll threw betsy under holmlea grille making these keep dead before coming diamonds standing agreed longer best sent leaf archie sitting expected clear which burst ever gather papers hours considered hundred perfectly see half entered stupid remember trouble note wanted archie seems eye rectory ready papers deep haven suddenly wasn should isn trouble piece envelope egg bring poor remark gone length fit anybody blackguard nothing fallconer board gentleman long murderer pocket getting river spot obviously fell interest burst surprised seems knows speak ready visitor poor bullet you used late ever law marjorie lit proved ready stavert light myself light understand live turn drink sometimes train outside question met smile chance believe during happened show amongst morrow fell bad grinned dog think just long realised complete miller envelope main how window give hadn used stuff wouldn already place near close interest atmosphere agreed thinking mean power miller wouldn do certainly or admit possible happened anything certainly distance anyone disappointed these word speak magnificent head great tragedy leaf ready water perhaps telephone clergyman name make new suggested flower because heart isn williams power quietly wait millington guardian local em bernard yesterday myself major death beside archie sight haven papers here never cross arrived seems five fell difficulty late standing gather understand considerable letters hands recognise gate name bad boy carrying entered country suddenly visitor words wanted drury place interesting yesterday many points extraordinary week further silence state betsy writing gate dinner knows destination service these spot certain corner may window interesting window diamonds sternly spoke keep sent, past turn words each interested first took put marjorie knows moments clear getting show pulled expression glanced right note tongue certainly envelope poor london certainly dark use shortly went afternoon woman night more death stapleton thank cottage d silence empty behind excellent longer front caused playfair live dangerous another distance ve haven there men someone yesterday isn always surely hands bath thing opened meant wonder arrived three without writing staring shall envelope interest late davidson closed reached surprised home surprised because between taking couldn evidently either possible stream with god miller shortly big people bird long great action really three marjorie met always turn wonder gone nodded right stuff hit suggested struck guardian this village slowly knowledge past proved too terrier say damned many isn envelope one known samples mentioned lady only death country
